# %%
import pandas as pd
import numpy as np

# %%
merg = pd.read_csv("MPPD.csv")

# %%
merg.head()
# Out:
#    row_id  loan_type  property_type  loan_purpose  occupancy  loan_amount  \
# 0       0          3              1             1          1           70
# 1       1          1              1             3          1          178
# 2       2          2              1             3          1          163
# 3       3          1              1             1          1          155
# 4       4          1              1             1          1          305
#
#    preapproval  msa_md  state_code  county_code  ...  applicant_income  \
# 0            3      18          37          246  ...              24.0
# 1            3     369          52          299  ...              57.0
# 2            3      16          10          306  ...              67.0
# 3            1     305          47          180  ...             105.0
# 4            3      24          37           20  ...              71.0
#
#    population  minority_population_pct  ffiecmedian_family_income  \
# ...

# %%
merg.isnull().sum()
# Out:
# row_id                                0
# loan_type                             0
# property_type                         0
# loan_purpose                          0
# occupancy                             0
# loan_amount                           0
# preapproval                           0
# msa_md                                0
# state_code                            0
# county_code                           0
# applicant_ethnicity                   0
# applicant_race                        0
# applicant_sex                         0
# applicant_income                  80089
# population                        44945
# minority_population_pct           44948
# ffiecmedian_family_income         44893
# tract_to_msa_md_income_pct        45031
# number_of_owner-occupied_units    45139
# number_of_1_to_4_family_units     45080
# lender                                0
# co_applicant                          0
# accepted                              0
# dtype: int64

# %%
## Replace data points with median values, accounting for mising values coded as '-1'
import numpy as np
import pandas as pd
cols = ['msa_md', 'state_code', 'county_code']
for column in cols:
    merg.loc[merg[column] == -1, column] = np.nan

# %%
merg.isnull().sum()
# Out:
# row_id                                 0
# loan_type                              0
# property_type                          0
# loan_purpose                           0
# occupancy                              0
# loan_amount                            0
# preapproval                            0
# msa_md                            153975
# state_code                         38252
# county_code                        41032
# applicant_ethnicity                    0
# applicant_race                         0
# applicant_sex                          0
# applicant_income                   80089
# population                         44945
# minority_population_pct            44948
# ffiecmedian_family_income          44893
# tract_to_msa_md_income_pct         45031
# number_of_owner-occupied_units     45139
# number_of_1_to_4_family_units      45080
# lender                                 0
# co_applicant                           0
# accepted                               0
# ...

# %%
merg.to_csv("newTrainTest.csv", index=False)

# %%
second = pd.read_csv("secondsub.csv")

# %%
second.head()
# Out:
#    accepted  applicant_income  loan_amount  loan_purpose-1  \
# 0         1          0.009859     0.001117               0
# 1         0          0.010331     0.002459               1
# 2         1          0.011501     0.002635               1
# 3         1          0.004191     0.001744               1
# 4         1          0.003021     0.000343               1
#
#    tract_to_msa_md_income_pct  ffiecmedian_family_income  \
# 0                    0.851904               4.448038e-02
# 1                    1.000000              -2.714998e-01
# 2                    0.914840               3.161205e-12
# 3                    1.000000              -7.926323e-01
# 4                    1.000000              -4.082910e-01
#
#    minority_population_pct    msa_md  number_of_1_to_4_family_units  \
# 0                 0.594073  0.247549                       0.176846
# 1                 0.077576  0.213235                       0.089047
# ...

# %%
seconddS = second[["row_id", "acceptednew"]]

# %%
seconddS.columns = ["row_id", "accepted"]
seconddS.tail(10)
# Out:
#         row_id  accepted
# 499990  499990         1
# 499991  499991         0
# 499992  499992         0
# 499993  499993         0
# 499994  499994         0
# 499995  499995         0
# 499996  499996         1
# 499997  499997         0
# 499998  499998         1
# 499999  499999         1

# %%
seconddS.to_csv("secondsubmission.csv", index=False)

# %%
third = pd.read_csv("Thirdsub.csv")

# %%
third.head()
# Out:
#    row_id  accepted
# 0       0         1
# 1       1         1
# 2       2         0
# 3       3         1
# 4       4         0

# %%
third.columns = ["row_id", "accepted"]

# %%
third.to_csv("thirdsubmission.csv", index=False)

# %%
fourth = pd.read_csv("FourthSub.csv")
fourth.head()
# Out:
#    row_id  Scored Labels
# 0       0              1
# 1       1              1
# 2       2              0
# 3       3              1
# 4       4              0

# %%
fourth.columns = ["row_id", "accepted"]

# %%
fourth.to_csv("fourthsubmission.csv", index=False)

# %%
fif = pd.read_csv("fifthsub.csv")
fif.head()
# Out:
#    row_id  Scored Labels
# 0       0              1
# 1       1              1
# 2       2              0
# 3       3              1
# 4       4              0

# %%
fif.columns = ["row_id", "accepted"]

# %%
fif.to_csv("fifthsubmission.csv", index=False)

# %%
six = pd.read_csv("sixthsub.csv")
six.head()
# Out:
#    row_id  Scored Labels
# 0       0              1
# 1       1              1
# 2       2              0
# 3       3              1
# 4       4              0

# %%
six.columns = ["row_id", "accepted"]

# %%
six.to_csv("sixthsubmission.csv", index=False)

# %%
sev = pd.read_csv("sevsub.csv")
sev.head()
# Out:
#    row_id  Scored Labels
# 0       0              1
# 1       1              1
# 2       2              0
# 3       3              1
# 4       4              0

# %%
sev.columns = ["row_id", "accepted"]

# %%
sev.to_csv("sevsubmission.csv", index=False)

# %%
eig = pd.read_csv("eigsub.csv")
eig.head()
# Out:
#    row_id  Scored Labels
# 0       0              1
# 1       1              1
# 2       2              0
# 3       3              1
# 4       4              0

# %%
eig.columns = ["row_id", "accepted"]

# %%
eig.to_csv("eigsubmission.csv", index=False)
